# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
lines = open('Kepler1656_test8.txt').readlines()
t = []
i1 = []
e1 = []
e2 = []
a1 = []
a2 = []
beta = []

for line in lines:
    l = [float(x) for x in line.split('\t')[:-1]]
    t.append(l[2])
    a1.append(l[7])
    a2.append(l[-10])
    e1.append(l[3])
    e2.append(l[4])
    i1.append(l[10])

# %%
plt.figure(figsize=(10,5))
plt.subplot(321);plt.plot(t,e1);plt.title('e1')#[1-i for i in e1])
plt.subplot(322);plt.plot(t,e2);plt.title('e2')
plt.subplot(323);plt.plot(t,a1);plt.title('a1')
plt.subplot(324);plt.plot(t,a2);plt.title('a2')
plt.subplot(325);plt.plot(t,i1);plt.title('i1')
# Out:
# Text(0.5,1,'i1')
